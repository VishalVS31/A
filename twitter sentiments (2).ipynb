# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\welcome\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: trio~=0.17 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: sortedcontainers in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sniffio in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\welcome\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\welcome\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\welcome\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\welcome\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep
import getpass

# %%
from selenium import webdriver
from time import sleep

PATH = "C:\Program Files\drivers\chromedriver.exe"
driver = webdriver.Chrome(PATH)

driver.get("https://twitter.com/i/flow/login")
# driver.maximize_window()
sleep(3)
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_10184\620006778.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)

# %%
my_user = "VishalS39768006"
my_pass = getpass.getpass()
# Out:
# ········

# %%
search_item = "artificial intelligence jobs"

# %%
from selenium import webdriver
from time import sleep

PATH = "C:\Program Files\drivers\chromedriver.exe"
driver = webdriver.Chrome(PATH)

driver.get("https://twitter.com/i/flow/login")
# driver.maximize_window()
sleep(3)
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_10184\620006778.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)

# %%
user_id = driver.find_element(By.XPATH,"//input[@type='text']")
user_id.send_keys(my_user)
user_id.send_keys(Keys.ENTER)

# %%
password = driver.find_element(By.XPATH,"//input[@type='password']")
password.send_keys(my_pass)
password.send_keys(Keys.ENTER)

# %%
# # Scrape Tweets mentioning about artificial intelligence

# %%
search_box = driver.find_element(By.XPATH,"//input[@data-testid='SearchBox_Search_Input']")
search_box.send_keys(search_item)
search_box.send_keys(Keys.ENTER)

# %%
# collecting twittes
all_tweets = set()


tweets = driver.find_elements(By.XPATH,"//div[@data-testid='tweetText']")
while True:
    for tweet in tweets:
        all_tweets.add(tweet.text)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    sleep(3)
    tweets = driver.find_elements(By.XPATH,"//div[@data-testid='tweetText']")
    if len(all_tweets)>100:
        break

# %%
all_tweets = list(all_tweets)
all_tweets[0]
# Out:
# '***Job Position: Lab Manager***\n\nWe are looking for a researcher with a broad experience in protein characterization (cloning, expression, purification).\n\nInterested? Send your CV to noelia.ferruz@ibmb.csic.es before May 15th\n\nMORE INFORMATION:'

# %%
# # Cleaning the Tweets

# %%
import pandas as pd
pd.options.display.max_colwidth = 1000
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\WELCOME\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\WELCOME\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
pd.options.display.max_colwidth = 1000
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\WELCOME\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\WELCOME\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stp_words = stopwords.words('english')
print(stp_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
df = pd.DataFrame(all_tweets,columns=['tweets'])
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                         tweets
# 0                                                                                   ***Job Position: Lab Manager***\n\nWe are looking for a researcher with a broad experience in protein characterization (cloning, expression, purification).\n\nInterested? Send your CV to noelia.ferruz@ibmb.csic.es before May 15th\n\nMORE INFORMATION:
# 1                                                                                                                                                                                                                  Artificial Intelligence Could Replace 80% Of Jobs In Coming Years: Expert\n#jobs #artificialintelligence #replace #thespuzz
# 2   Job Alert! We are offering a PhD position in Explainable AI in Healthcare. \n\nReady to join the NWA Load project developing and applying Explainable AI in the healthcare and well-being domain and participating in cutting-edge research?\n\n\nhttps://jobs.tue.nl/en/vacancy/phd-position-in-explainable-ai-in-healthcare-992353.html…
# 3                                                                                                                                                                                                                                                   7,800 jobs under threat at IBM as it looks towards relying more on artificial intelligence
# 4                                                                                                                                                                                                  The rise of automation and artificial intelligence could lead to job displacement and income inequality. #IncomeEquality #TechRisk #Aiville

# %%
one_tweet=df.iloc[4]['tweets']
one_tweet
# Out:
# ' The rise of automation and artificial intelligence could lead to job displacement and income inequality. #IncomeEquality #TechRisk #Aiville'

# %%
# !pip install textblob
# !pip install wordcloud
# Out:
# Requirement already satisfied: textblob in c:\users\welcome\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\welcome\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\welcome\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\welcome\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.1)
# Requirement already satisfied: tqdm in c:\users\welcome\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in c:\users\welcome\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in c:\users\welcome\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Requirement already satisfied: wordcloud in c:\users\welcome\anaconda3\lib\site-packages (1.9.1.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\welcome\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\welcome\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\welcome\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\welcome\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\welcome\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
def TweetCleaning(tweet):
    cleanTweet = re.sub(r"@[a-zA-Z0-9]+","",tweet)
    cleanTweet = re.sub(r"#[a-zA-Z0-9\s]+","",cleanTweet)
    cleanTweet = ' '.join(word for word in cleanTweet.split() if word not in stp_words)
    return cleanTweet

# %%
from textblob import TextBlob
from wordcloud import WordCloud

# %%
def calPolarity(tweet):
    return TextBlob(tweet).sentiment.polarity

# %%
def calSubjectivity(tweet):
    return TextBlob(tweet).sentiment.subjectivity

# %%
def segmentation(tweet):
    if tweet > 0:
        return "positive"
    if tweet == 0:
        return "neutral"
    else:
        return "negative"

# %%
df['cleanedTweets'] = df['tweets'].apply(TweetCleaning)
df['tPolarity'] = df['cleanedTweets'].apply(calPolarity)
df['tSubjectivity'] = df['cleanedTweets'].apply(calSubjectivity)
df['segmentation'] = df['tPolarity'].apply(segmentation)
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                         tweets  \
# 0                                                                                   ***Job Position: Lab Manager***\n\nWe are looking for a researcher with a broad experience in protein characterization (cloning, expression, purification).\n\nInterested? Send your CV to noelia.ferruz@ibmb.csic.es before May 15th\n\nMORE INFORMATION:
# 1                                                                                                                                                                                                                  Artificial Intelligence Could Replace 80% Of Jobs In Coming Years: Expert\n#jobs #artificialintelligence #replace #thespuzz
# 2   Job Alert! We are offering a PhD position in Explainable AI in Healthcare. \n\nReady to join the NWA Load project developing and applying Explainable AI in the healthcare and well-being domain and participating in cutting-edge research?\n\n\nhttps://jobs.tue.nl/en/vacancy/phd-position-in-explainable-ai-in-healthcare-992353.html…
# 3                                                                                                                                                                                                                                                   7,800 jobs under threat at IBM as it looks towards relying more on artificial intelligence
# 4                                                                                                                                                                                                  The rise of automation and artificial intelligence could lead to job displacement and income inequality. #IncomeEquality #TechRisk #Aiville
#
#                                                                                                                                                                                                                                                                               cleanedTweets  \
# 0                                                                                 ***Job Position: Lab Manager*** We looking researcher broad experience protein characterization (cloning, expression, purification). Interested? Send CV noelia.ferruz.csic.es May 15th MORE INFORMATION:
# 1                                                                                                                                                                                                                 Artificial Intelligence Could Replace 80% Of Jobs In Coming Years: Expert
# 2  Job Alert! We offering PhD position Explainable AI Healthcare. Ready join NWA Load project developing applying Explainable AI healthcare well-being domain participating cutting-edge research? https://jobs.tue.nl/en/vacancy/phd-position-in-explainable-ai-in-healthcare-992353.html…
# 3                                                                                                                                                                                                                       7,800 jobs threat IBM looks towards relying artificial intelligence
# 4                                                                                                                                                                                                The rise automation artificial intelligence could lead job displacement income inequality.
#
#    tPolarity  tSubjectivity segmentation
# 0   0.270833         0.4375     positive
# 1  -0.600000         1.0000     negative
# 2   0.200000         0.5000     positive
# 3  -0.600000         1.0000     negative
# 4  -0.600000         1.0000     negative

# %%
# # Analysis and Visualization

# %%
df.pivot_table(index=['segmentation'],aggfunc={'segmentation':'count'})
# Out:
#               segmentation
# segmentation
# negative                56
# neutral                 16
# positive                35

# %%
# top 3 most negative
df.sort_values(by=['tPolarity'],ascending=True).head(3)
# Out:
#                                                                                                                                                                                                                                                                                                     tweets  \
# 106                                                                                                                          Will Artificial Intelligence Take My Job? Let's Discuss AI's Impact https://youtube.com/live/PGTN9yS232o?feature=share… via \n@YouTube\n #ArtificialIntelligence #ai #chatgpt
# 1                                                                                                                                                                              Artificial Intelligence Could Replace 80% Of Jobs In Coming Years: Expert\n#jobs #artificialintelligence #replace #thespuzz
# 46   Tune in tomorrow 5/10/23 show releases on \n@youtube\n at 830am pst \n@tonetalks\n Youtube. "Will Artificial Intelligence AI & Robots take all the jobs in America?" \nWatch Here: https://youtu.be/JH4Jc8yoaPo  \nHere is a preview section from the show where I give a scathing review of #AB3121…
#
#                                                                                                                                                                                                         cleanedTweets  \
# 106                                                                                       Will Artificial Intelligence Take My Job? Let's Discuss AI's Impact https://youtube.com/live/PGTN9yS232o?feature=share… via
# 1                                                                                                                                           Artificial Intelligence Could Replace 80% Of Jobs In Coming Years: Expert
# 46   Tune tomorrow 5/10/23 show releases 830am pst Youtube. "Will Artificial Intelligence AI & Robots take jobs America?" Watch Here: https://youtu.be/JH4Jc8yoaPo Here preview section show I give scathing review …
#
#      tPolarity  tSubjectivity segmentation
# 106       -0.6            1.0     negative
# 1         -0.6            1.0     negative
# 46        -0.6            1.0     negative

# %%
# 3 neutral
df[df.tPolarity==0].head(3)
# Out:
#                                                                                                                                                                                                                                                 tweets  \
# 22  How concerned are you about your job with the rise of AI? #ArtificialIntelligence #chatgtp https://linkedin.com/posts/donjanderson_chatgpt-artificialintelligence-ai-activity-7060121192506036224-nyk1?utm_source=share&utm_medium=member_desktop…
# 30                                                                                                                      IBM REPLACING 7,800 HUMAN JOBS WITH AI, INCLUDING HUMAN RESOURCES #Cyberpunk #TTRPG #RPG #ArtificialIntelligence #Unemployment
# 40                                                                                                                                      #ArtificialIntelligence may eliminate "80 percent of jobs" in the coming years\n#PublicPresse #PublicPresse_EN
#
#                                                                                                                                                                     cleanedTweets  \
# 22  How concerned job rise AI? ://linkedin.com/posts/donjanderson_chatgpt-artificialintelligence-ai-activity-7060121192506036224-nyk1?utm_source=share&utm_medium=member_desktop…
# 30                                                                                                              IBM REPLACING 7,800 HUMAN JOBS WITH AI, INCLUDING HUMAN RESOURCES
# 40                                                                                                                                             "80 percent jobs" coming years _EN
#
#     tPolarity  tSubjectivity segmentation
# 22        0.0            0.0      neutral
# 30        0.0            0.1      neutral
# 40        0.0            0.0      neutral

# %%
# top 3 most positive
df.sort_values(by=['tPolarity'],ascending=False).head(3)
# Out:
#                                                                                                                                                                                                                              tweets  \
# 103                                         #NSTworld #Artificialintelligence could replace 80 percent of human #jobs in the coming years – but that's a good thing, says US-Brazilian researcher #BenGoertzel, a leading #AI guru.
# 70   Worried about AI taking your job? If you're a bureaucrat, you may be quite safe. Here's where AI may meet it's match: https://gilescrouch.medium.com/bureaucracy-meets-artificial-intelligence-fa5212c68b03… #SaturdayThoughts
# 97                                                                                                                                                                                     Which Jobs Will Be Most Impacted by ChatGPT?
#
#                                                                                                                                                               cleanedTweets  \
# 103                                                                                                           – that's good thing, says US-Brazilian researcher , leading .
# 70   Worried AI taking job? If bureaucrat, may quite safe. Here's AI may meet match: https://gilescrouch.medium.com/bureaucracy-meets-artificial-intelligence-fa5212c68b03…
# 97                                                                                                                                Which Jobs Will Be Most Impacted ChatGPT?
#
#      tPolarity  tSubjectivity segmentation
# 103        0.7            0.6     positive
# 70         0.5            0.5     positive
# 97         0.5            0.5     positive

# %%
import matplotlib.pyplot as plt

# %%
consolidated = ' '.join(word for word in df['cleanedTweets'])

# %%
wordCloud = WordCloud(width=5000, height=6666, random_state=15, max_font_size=1100,).generate(consolidated)

# %%
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordCloud = WordCloud(width=1280, height=640, random_state=15, max_font_size=120,).generate(consolidated)

# %%
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import seaborn as sns

# %%
df.groupby('segmentation').count()
# Out:
#               tweets  cleanedTweets  tPolarity  tSubjectivity
# segmentation
# negative          56             56         56             56
# neutral           16             16         16             16
# positive          35             35         35             35

# %%
plt.figure(figsize=(10,5))
sns.set_style("whitegrid")
sns.scatterplot(data=df, x='tPolarity',y='tSubjectivity',s=100,hue='segmentation')
# Out:
# <Axes: xlabel='tPolarity', ylabel='tSubjectivity'>

# %%
sns.countplot(data=df,x='segmentation')
# Out:
# <Axes: xlabel='segmentation', ylabel='count'>

# %%
positive = round(len(df[df.segmentation == 'positive'])/len(df)*100,1)
negative = round(len(df[df.segmentation == 'negative'])/len(df)*100,1)
neutral = round(len(df[df.segmentation == 'neutral'])/len(df)*100,1)

responses = [positive, negative, neutral]
responses

response = {'resp': ['Excited', 'Afraid', 'Confused'], 'pct':[positive, negative, neutral]}
pd.DataFrame(response)
# Out:
#        resp   pct
# 0   Excited  32.7
# 1    Afraid  52.3
# 2  Confused  15.0
